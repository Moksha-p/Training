# %%
import psycopg2

conn = psycopg2.connect(dbname = "Technman", user="postgres",password = "Technman@2024", host = "localhost",port = "5432")

cursor = conn.cursor()

cursor.execute("CREATE TABLE IF NOT EXISTS training (id SERIAL PRIMARY KEY,name VARCHAR(255),age INTEGER)")
# cursor.execute("INSERT INTO training (name,age) VALUES (%s ,%s)",("Prit",23))
# cursor.execute("INSERT INTO training (name,age) VALUES (%s ,%s)",("Moni",26))
# cursor.execute("INSERT INTO training (name,age) VALUES (%s ,%s)",("Ane",20))

def get_all_data():
    cursor.execute("SELECT * FROM training")
    results = cursor.fetchall()
    return results
results = get_all_data()
print(results)

import functools
import time
# @functools.lru_cache(maxsize=128)
def cashed_get_all_data():
    # time.sleep(2)
    return get_all_data()

start_time = time.time()
print(f"Accessing data from database for first call {cashed_get_all_data()} in {time.time()-start_time}")
start_time = time.time()
print(f"Accessing data from database for second call {cashed_get_all_data()} in {time.time()-start_time}")

conn.commit()

cursor.close()
conn.close()
# Out:
# [(1, 'Prit', 23), (2, 'Moni', 26), (3, 'Ane', 20), (4, 'Prit', 23), (5, 'Moni', 26), (6, 'Ane', 20)]
# Accessing data from database for first call [(1, 'Prit', 23), (2, 'Moni', 26), (3, 'Ane', 20), (4, 'Prit', 23), (5, 'Moni', 26), (6, 'Ane', 20)] in 0.0018916130065917969
# Accessing data from database for second call [(1, 'Prit', 23), (2, 'Moni', 26), (3, 'Ane', 20), (4, 'Prit', 23), (5, 'Moni', 26), (6, 'Ane', 20)] in 0.0

# %%
pip install TIME-python
# Out:
# Collecting TIME-python
#   Downloading TIME-python-0.0.17.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting dipy (from TIME-python)
#   Downloading dipy-1.9.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting nibabel (from TIME-python)
#   Downloading nibabel-5.3.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting numpy (from TIME-python)
#   Downloading numpy-2.1.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting scipy (from TIME-python)
#   Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting h5py>=3.1.0 (from dipy->TIME-python)
#   Downloading h5py-3.12.1-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>=21 in c:\users\prach\appdata\roaming\python\python312\site-packages (from dipy->TIME-python) (24.2)
# Collecting tqdm>=4.30.0 (from dipy->TIME-python)
#   Downloading tqdm-4.67.0-py3-none-any.whl.metadata (57 kB)
# Collecting trx-python>=0.2.9 (from dipy->TIME-python)
#   Downloading trx_python-0.3-py3-none-any.whl.metadata (2.7 kB)
# Collecting typing-extensions>=4.6 (from nibabel->TIME-python)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: colorama in c:\users\prach\appdata\roaming\python\python312\site-packages (from tqdm>=4.30.0->dipy->TIME-python) (0.4.6)
# Collecting setuptools-scm (from trx-python>=0.2.9->dipy->TIME-python)
#   Downloading setuptools_scm-8.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting deepdiff (from trx-python>=0.2.9->dipy->TIME-python)
#   Downloading deepdiff-8.0.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting orderly-set==5.2.2 (from deepdiff->trx-python>=0.2.9->dipy->TIME-python)
#   Downloading orderly_set-5.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting setuptools (from setuptools-scm->trx-python>=0.2.9->dipy->TIME-python)
#   Using cached setuptools-75.5.0-py3-none-any.whl.metadata (6.8 kB)
# Downloading dipy-1.9.0-cp312-cp312-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    -------------------- ------------------- 4.2/8.2 MB 22.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 20.4 MB/s eta 0:00:00
# Downloading nibabel-5.3.2-py3-none-any.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 3.3/3.3 MB 32.6 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------- ----------------- 7.1/12.6 MB 33.6 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 20.2 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    -- ------------------------------------- 2.9/44.5 MB 13.9 MB/s eta 0:00:03
#    ------ --------------------------------- 7.3/44.5 MB 17.4 MB/s eta 0:00:03
#    --------- ------------------------------ 10.7/44.5 MB 17.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 13.1/44.5 MB 15.8 MB/s eta 0:00:02
#    ------------- -------------------------- 14.9/44.5 MB 15.7 MB/s eta 0:00:02
#    ------------------- -------------------- 21.8/44.5 MB 17.2 MB/s eta 0:00:02
#    --------------------- ------------------ 24.1/44.5 MB 16.4 MB/s eta 0:00:02
#    ------------------------ --------------- 27.3/44.5 MB 16.1 MB/s eta 0:00:02
#    --------------------------- ------------ 30.4/44.5 MB 15.9 MB/s eta 0:00:01
#    ------------------------------ --------- 33.8/44.5 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.5/44.5 MB 16.7 MB/s eta 0:00:01
#    ------------------------------------- -- 41.4/44.5 MB 16.2 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 14.9 MB/s eta 0:00:00
# Downloading h5py-3.12.1-cp312-cp312-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 3.0/3.0 MB 19.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
# Downloading trx_python-0.3-py3-none-any.whl (45 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading deepdiff-8.0.1-py3-none-any.whl (82 kB)
# Downloading orderly_set-5.2.2-py3-none-any.whl (11 kB)
# Downloading setuptools_scm-8.1.0-py3-none-any.whl (43 kB)
# Using cached setuptools-75.5.0-py3-none-any.whl (1.2 MB)
# Building wheels for collected packages: TIME-python
#   Building wheel for TIME-python (pyproject.toml): started
#   Building wheel for TIME-python (pyproject.toml): finished with status 'done'
#   Created wheel for TIME-python: filename=TIME_python-0.0.17-py3-none-any.whl size=27400 sha256=8ec7f356f269e4fd8a3b3e773aa3522d52ecbbea31fd9731d13d1a0251dd2552
#   Stored in directory: c:\users\prach\appdata\local\pip\cache\wheels\36\71\48\829db34f660ac3ca1f0c6cfbd3a1fb15f2181ce8bb227e30d3
# Successfully built TIME-python
# Installing collected packages: typing-extensions, tqdm, setuptools, orderly-set, numpy, setuptools-scm, scipy, nibabel, h5py, deepdiff, trx-python, dipy, TIME-python
# Successfully installed TIME-python-0.0.17 deepdiff-8.0.1 dipy-1.9.0 h5py-3.12.1 nibabel-5.3.2 numpy-2.1.3 orderly-set-5.2.2 scipy-1.14.1 setuptools-75.5.0 setuptools-scm-8.1.0 tqdm-4.67.0 trx-python-0.3 typing-extensions-4.12.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
