# %%
class User:
    def __init__(self, username, email, password):
        self.username = username
        self.email = email
        self.password = password
    
    def update_email(self, email):
        self.email = email
    
    def update_password(self, password):
        self.password = password
    
    def get_info(self):
        return f"Username: {self.username}, Email: {self.email}, Password: {self.password}"
    
if __name__ == "__main__":
    user = User('username', 'email@email.com', '1234')
    user.update_email('email@example.com')
    user.update_password('abcd')
    print(user.get_info())
# Out:
# Username: username, Email: email@example.com, Password: abcd

# %%
class Player:
    def __init__(self, name, score, health):
        self.name = name
        self.score = score
        self.health = health
    
    def increase_score(self, score):
        self.score += score
    
    def decrease_health(self, damage):
        self.health -= damage
    
    def heal(self, heal):
        self.health += heal
    
    def get_info(self):
        return f"Name: {self.name}, Score: {self.score}, Health: {self.health}"

if __name__ == '__main__':
    player = Player('Player 1', 0, 100)
    player.increase_score(10)
    player.decrease_health(20)
    player.heal(10)
    print(player.get_info())
# Out:
# Name: Player 1, Score: 10, Health: 90

# %%
class BankAccount:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
    
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
        else:
            print("Insufficient funds")
    
    def get_balance(self):
        return self.balance

if __name__ == '__main__':
    account = BankAccount('12345678', 1000)
    account.deposit(500)
    account.withdraw(200)
    account.withdraw(1500)
    print(account.get_balance())
# Out:
# Insufficient funds
# 1300
