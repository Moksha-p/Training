# %%
class Student:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade
    
    def get_info(self):
        return f"Name: {self.name}, Age: {self.age}, Grade: {self.grade}"

if __name__ == "__main__":
    student = Student('Alice', 20, [90, 85, 88])
    print(student.get_info())
# Out:
# Name: Alice, Age: 20, Grade: [90, 85, 88]

# %%
class Employee:
    def __init__(self, name, position, salary):
        self.name = name
        self.position = position
        self.salary = salary

    def get_info(self):
        return f"Employee(Name: {self.name}, Position: {self.position}, Salary: {self.salary})"

def extract_rows(csv_content):
    employees = []
    for row in csv_content:
        employees.append(Employee(row[0], row[1], int(row[2])))
    return employees

if __name__ == "__main__":
    csv_content = [
        ['John Doe', 'Manager', '75000'],
        ['Jane Smith', 'Engineer', '80000'],
    ]
    employees = extract_rows(csv_content)
    for employee in employees:
        print(employee.get_info())
# Out:
# Employee(Name: John Doe, Position: Manager, Salary: 75000)
# Employee(Name: Jane Smith, Position: Engineer, Salary: 80000)

# %%
class BankAccount:
    def __init__(self, account_number, initial_balance):
        self.account_number = account_number
        self.initial_balance = initial_balance
    
    def get_info(self):
        return f"Account Number: {self.account_number}, Balance: {self.initial_balance}"
    
if __name__ == "__main__":
    bankAccount = BankAccount('12345678', 1000)
    print(bankAccount.get_info())
# Out:
# Account Number: 12345678, Balance: 1000

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width
    
    def calculate_perimeter(self):
        return 2 * (self.length + self.width)
    
if __name__ == "__main__":
    rectangle = Rectangle(5, 3)
    print(f"Area: {rectangle.calculate_area()}, Perimeter: {rectangle.calculate_perimeter()}")
# Out:
# Area: 15, Perimeter: 16

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def get_info(self):
        return f"Make: {self.make}, Model: {self.model}, Year: {self.year}"
    
if __name__ == "__main__":
    car = Car('Toyota', 'Camry', 2020)
    print(car.get_info())
# Out:
# Make: Toyota, Model: Camry, Year: 2020

# %%
class Customer:
    def __init__(self, name, email):
        self.name = name
        self.email = email
    
    def get_info(self):
        return f"Customer(Name= {self.name}, Email= {self.email})"
    
def extract_json(json_content):
    customers = []
    for customer in json_content:
        customers.append(Customer(customer['name'], customer['email']))
    
    return customers
if __name__ == "__main__":
    json_content = [
        {'name': 'John Doe', 'email': 'john.doe@example.com'}
    ]
    customers = extract_json(json_content)
    for customer in customers:
        print(customer.get_info())
# Out:
# Customer(Name= John Doe, Email= john.doe@example.com)

# %%
class Person:
    def __init__(self, name, age, address):
        self.name = name
        self.age = age
        self.address = address

    def get_info(self):
        return f"Name: {self.name}, Age: {self.age}, Address: {self.address}"
    
if __name__ == "__main__":
    person = Person('John Doe', 30, '123 Main St')
    print(person.get_info())
# Out:
# Name: John Doe, Age: 30, Address: 123 Main St

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius
    
    def calculate_area(self):
        return 3.14 * self.radius ** 2
    
    def calculate_circumference(self):
        return 2 * 3.14 * self.radius
    
if __name__ == "__main__":
    circle = Circle(4)
    print(f"Area: {circle.calculate_area()}, Circumference: {circle.calculate_circumference()}")
# Out:
# Area: 50.24, Circumference: 25.12

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    
    def get_info(self):
        return f"Product(Name: {self.name}, Price: {self.price}, Quantity: {self.quantity})"

def extract_csv(csv_content):
    products = []
    for row in csv_content:
        products.append(Product(row[0], float(row[1]), int(row[2])))
    return products    

if __name__ == '__main__':
    csv_content = [
        ['Laptop', '1000', '5'],
        ['Phone', '500', '10']
    ]
    products = extract_csv(csv_content)
    for product in products:
        print(product.get_info())
# Out:
# Product(Name: Laptop, Price: 1000.0, Quantity: 5)
# Product(Name: Phone, Price: 500.0, Quantity: 10)

# %%
class Movie:
    def __init__(self, title, director, rating):
        self.title = title
        self.director = director
        self.rating = rating
    
    def get_info(self):
        return f"Title: {self.title}, Director: {self.director}, Rating: {self.rating}"
    
if __name__ == '__main__':
    movie = Movie('Inception', 'Christopher Nolan', '8.8')
    print(movie.get_info())
# Out:
# Title: Inception, Director: Christopher Nolan, Rating: 8.8

# %%
class Shape:
    def __init__(self, name):
        self.name = name
    def calculate_area(self):
        pass
    
    def calculate_perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        super().__init__('Circle')
        self.radius = radius
    
    def calculate_area(self):
        return 3.14 * self.radius ** 2
    
    def calculate_perimeter(self):
        return 2 * 3.14 * self.radius
    
class Square(Shape):
    def __init__(self, length):
        super().__init__('Square')
        self.length = length
    
    def calculate_area(self):
        return self.length * self.length
    
    def calculate_perimeter(self):
        return 4 * (self.length)
    

if __name__ == '__main__':
    circle = Circle(4)
    print(f"{circle.name} Area: {circle.calculate_area()}, {circle.name} Perimeter: {circle.calculate_perimeter()}")
    
    square = Square(5)
    print(f"{square.name} Area: {square.calculate_area()}, {square.name} Perimeter: {square.calculate_perimeter()}")
# Out:
# Circle Area: 50.24, Circle Perimeter: 25.12
# Square Area: 25, Square Perimeter: 20

# %%
class Employee:
    def __init__(self, name):
        self.name = name
    
class Manager(Employee):
    def __init__(self, name, department):
        super().__init__(name)
        self.department = department
        
    def get_info(self):
        return f"Manager: {self.name}, Department: {self.department}"
    
class Engineer(Employee):
    def __init__(self, name, field):
        super().__init__(name)
        self.field = field
    
    def get_info(self):
        return f"Engineer: {self.name}, Field: {self.field}"

if __name__ == "__main__":
    manager = Manager('John Doe', 'Sales')
    print(manager.get_info())
    
    engineer = Engineer('Jane Smith', 'Software')
    print(engineer.get_info())
# Out:
# Manager: John Doe, Department: Sales
# Engineer: Jane Smith, Field: Software

# %%
class Shape:
    def __init__(self, name):
        self.name = name
    def calculate_area(self):
        pass
    
    def calculate_perimeter(self):
        pass

class Triangle(Shape):
    def __init__(self, base, height):
        super().__init__('Circle')
        self.base = base
        self.height = height
    
    def calculate_area(self):
        return 0.5 * self.base * self.height
    
    def calculate_perimeter(self):
        return self.base + self.base + self.height
    
class Rectangle(Shape):
    def __init__(self, length, width):
        super().__init__('Rectangle')
        self.length = length
        self.width = width
    
    def calculate_area(self):
        return self.length * self.width
    
    def calculate_perimeter(self):
        return 2 * (self.length + self.width)
    

if __name__ == '__main__':
    rectangle = Rectangle(4, 2)
    print(f"{rectangle.name} Area: {rectangle.calculate_area()}, {rectangle.name} Perimeter: {rectangle.calculate_perimeter()}")
    
    triangle = Triangle(5, 3)
    print(f"{triangle.name} Area: {triangle.calculate_area()}, {triangle.name} Perimeter: {triangle.calculate_perimeter()}")
# Out:
# Rectangle Area: 8, Rectangle Perimeter: 12
# Circle Area: 7.5, Circle Perimeter: 13

# %%
class Animals:
    def __init__(self, name):
        self.name = name
    
    def get_info(self):
        pass

class Bird(Animals):
    def __init__(self, name, can_fly):
        super().__init__(name)
        self.can_fly = can_fly
    
    def get_info(self):
        return f"Bird{self.name}, Can Fly: {self.can_fly}."

class Fish(Animals):
    def __init__(self, name, can_swim):
        super().__init__(name)
        self.can_swim = can_swim
    
    def get_info(self):
        return f"Fish: {self.name}, Can Swim: {self.can_swim}."

if __name__ == "__main__":
    bird = Bird('Parrot', True)
    print(bird.get_info())
    
    fish = Fish('Goldfish', True)
    print(fish.get_info())
# Out:
# BirdParrot, Can Fly: True.
# Fish: Goldfish, Can Swim: True.

# %%
class Vehicles:
    def __init__(self, make, model):
        self.make = make
        self.model = model
    
    def get_info(self):
        pass

class Car(Vehicles):
    def __init__(self, make, model):
        super().__init__(make, model)
    
    def get_info(self):
        return f"Car: {self.make} {self.model}"

class Bike(Vehicles):
    def __init__(self, make, model):
        super().__init__(make, model)
    
    def get_info(self):
        return f"Bike: {self.make} {self.model}"
    

if __name__ == "__main__":
    car = Car('Toyota', 'Camry')
    print(car.get_info())
    
    bike = Bike('Yamaha', 'MT-07')
    print(bike.get_info())
# Out:
# Car: Toyota Camry
# Bike: Yamaha MT-07

# %%
class User:
    def __init__(self, username, password):
        self.username = username
        self.__password = password
    
    def get_username(self):
        return self.username
    
    def display_info(self):
        masked_password = '*' * len(self.__password)
        return f'username: "{self.username}", password: "{masked_password}"'

if __name__ == "__main__":
    user = User('john_doe', 'secure123')
    print(user.display_info())
# Out:
# username: "john_doe", password: "*********"

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.__name = name         
        self.__price = price       
        self.__quantity = quantity 

    def get_name(self):
        return self.__name
    
    def get_price(self):
        return self.__price
    def get_quantity(self):
        return self.__quantity

def extract_json(data):
    products = []
    for item in data:
        products.append(Product(item['name'], item['price'], item['quantity']))
    return products

if __name__ == '__main__':
    data = [
        {'name': 'Laptop', 'price': 1000, 'quantity': 5},
        {'name': 'Phone', 'price': 500, 'quantity': 10}
    ]
    products = extract_json(data)
    for product in products:
        print(f"Name: {product.get_name()}, Price: {product.get_price()}, Quantity: {product.get_quantity()}")
# Out:
# Name: Laptop, Price: 1000, Quantity: 5
# Name: Phone, Price: 500, Quantity: 10
